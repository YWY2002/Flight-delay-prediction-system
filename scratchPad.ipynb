# %%
import pyarrow.parquet as pq
import polars as pl
from pathlib import Path
import os

path = f"{os.getcwd()}/data/bronze/opensky/2026-08/opensky_24082026.parquet"
df = pl.read_parquet(path)
table = pq.read_metadata(path)
print(table.schema)
print(df.head())
print(df.shape)
# Out:
# ...
# required group field_id=-1 schema {
#   required binary field_id=-1 icao24 (String);
#   optional binary field_id=-1 callsign (String);
#   optional binary field_id=-1 origin_country (String);
#   optional int64 field_id=-1 time_position;
#   optional int64 field_id=-1 last_contact;
#   optional double field_id=-1 longitude;
#   optional double field_id=-1 latitude;
#   optional double field_id=-1 baro_altitude;
#   optional boolean field_id=-1 on_ground;
#   optional double field_id=-1 velocity;
#   optional double field_id=-1 true_track;
#   optional double field_id=-1 vertical_rate;
#   optional group field_id=-1 sensors (List) {
#     repeated group field_id=-1 list {
#       optional int32 field_id=-1 element;
#     }
#   }
#   optional double field_id=-1 geo_altitude;
#   optional binary field_id=-1 squawk (String);
#   optional boolean field_id=-1 spi;
#   optional int32 field_id=-1 position_source (Int(bitWidth=8, isSigned=true));
# ...
